# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in d:\code\python\python-learn\conda_example\venv1\lib\site-packages (3.9.1)
# Requirement already satisfied: click in d:\code\python\python-learn\conda_example\venv1\lib\site-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in d:\code\python\python-learn\conda_example\venv1\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in d:\code\python\python-learn\conda_example\venv1\lib\site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in d:\code\python\python-learn\conda_example\venv1\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in d:\code\python\python-learn\conda_example\venv1\lib\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
corpus = """Hello this is a test Jupyter script for pre processing. 
I'm learning the basics of NLP.
7 April 2025"""

# %%
from nltk.tokenize import sent_tokenize

# %%
document = sent_tokenize(corpus)

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\indra\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
document = sent_tokenize(corpus)

# %%
from nltk.tokenize import sent_tokenize
document = sent_tokenize(corpus)

# %%
print(document)
# Out:
# ['Hello this is a test Jupyter script for pre processing.', "I'm learning the basics of NLP.", '7 April 2025']

# %%
from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['Hello',
#  'this',
#  'is',
#  'a',
#  'test',
#  'Jupyter',
#  'script',
#  'for',
#  'pre',
#  'processing',
#  '.',
#  'I',
#  "'m",
#  'learning',
#  'the',
#  'basics',
#  'of',
#  'NLP',
#  '.',
#  '7',
#  'April',
#  '2025']

# %%
from nltk.tokenize.treebank import TreebankWordTokenizer

# %%
tokenizer = TreebankWordTokenizer()

# %%
corpus = """Hello this is a test Jupyter script for pre processing. 
I'm learning the basics of NLP.
7 April 2025"""
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  'this',
#  'is',
#  'a',
#  'test',
#  'Jupyter',
#  'script',
#  'for',
#  'pre',
#  'processing.',
#  'I',
#  "'m",
#  'learning',
#  'the',
#  'basics',
#  'of',
#  'NLP.',
#  '7',
#  'April',
#  '2025']
