# %%
words = ["eating","eats","eaten","writing","writes","programming","programs","history","finally","finalized", "fairly", "sportingly"]

# %%
from nltk.stem import WordNetLemmatizer

# %%
lemmatizer = WordNetLemmatizer()

# %%
lemmatizer.lemmatize('going')
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# File D:\Code\Python\python-learn\conda_example\venv1\lib\site-packages\nltk\corpus\util.py:84, in LazyCorpusLoader.__load(self)
#      83 try:
# ---> 84     root = nltk.data.find(f"{self.subdir}/{zip_name}")
#      85 except LookupError:
#
# File D:\Code\Python\python-learn\conda_example\venv1\lib\site-packages\nltk\data.py:579, in find(resource_name, paths)
#     578 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 579 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource wordnet not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('wordnet')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/wordnet.zip/wordnet/
#
#   Searched in:
# ...

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\indra\AppData\Roaming\nltk_data...
# True

# %%
lemmatizer.lemmatize('going')
# Out:
# 'going'

# %%
lemmatizer.lemmatize('going', 'v')
# Out:
# 'go'

# %%
for word in words:
    print(word + ' --> ' + lemmatizer.lemmatize(word))
# Out:
# eating --> eating
# eats --> eats
# eaten --> eaten
# writing --> writing
# writes --> writes
# programming --> programming
# programs --> program
# history --> history
# finally --> finally
# finalized --> finalized
# fairly --> fairly
# sportingly --> sportingly

# %%
words = [
    { "word": "ran", "type": "v" },
    { "word": "beauty", "type": "a" },
    { "word": "quick", "type": "r" },
    { "word": "happiness", "type": "n" },
    { "word": "eaten", "type": "v" },
    { "word": "strong", "type": "a" },
    { "word": "slowly", "type": "r" },
    { "word": "computer", "type": "n" },
    { "word": "thinking", "type": "v" },
    { "word": "friendly", "type": "a" },
    { "word": "silently", "type": "r" },
    { "word": "city", "type": "n" },
    { "word": "jumping", "type": "v" },
    { "word": "brighten", "type": "a" },
    { "word": "loudly", "type": "r" }
]

# %%
for word in words:
    print(word['word'] + ' ---> ' + lemmatizer.lemmatize(word['word'], word['type']))
# Out:
# ran ---> run
# beauty ---> beauty
# quick ---> quick
# happiness ---> happiness
# eaten ---> eat
# strong ---> strong
# slowly ---> slowly
# computer ---> computer
# thinking ---> think
# friendly ---> friendly
# silently ---> silently
# city ---> city
# jumping ---> jump
# brighten ---> brighten
# loudly ---> loudly
